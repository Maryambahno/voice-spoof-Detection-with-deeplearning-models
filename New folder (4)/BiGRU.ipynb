# %%
import json
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from sklearn.model_selection import train_test_split
from sklearn.metrics import (roc_curve, precision_recall_curve, auc,
                            confusion_matrix, ConfusionMatrixDisplay,
                            classification_report, accuracy_score)
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

# ==============================================================
# 0. Configuration & Reproducibility
# ==============================================================
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

# Official ASVspoof 2019 Challenge Parameters
ASV_PARAMS = {
    'Pmiss_asv': 0.01, 'Pfa_asv': 0.001, 'Pmiss_spoof_asv': 0.05,
    'Cmiss_asv': 1, 'Cfa_asv': 1, 'Cmiss_cm': 1, 'Cfa_cm': 10,
    'pi_tar': 0.9405, 'pi_non': 0.0095, 'pi_spoof': 0.05
}

# ==============================================================
# Mask-Compatible Augmentation Layers
# ==============================================================
class TimeMasking(tf.keras.layers.Layer):
    def __init__(self, max_mask_length=10):
        super().__init__()
        self.max_mask_length = max_mask_length
        self.supports_masking = True  # Enable mask propagation

    def call(self, inputs, training=None):
        if not training:
            return inputs

        def _apply_time_mask(input_slice):
            time_steps = tf.shape(input_slice)[0]
            features = tf.shape(input_slice)[1]

            T = tf.random.uniform(shape=[], maxval=self.max_mask_length, dtype=tf.int32)
            T = tf.minimum(T, time_steps)
            t0 = tf.random.uniform(shape=[], maxval=time_steps - T, dtype=tf.int32)

            # Create 2D mask with broadcasting
            mask = tf.ones((time_steps, 1), dtype=tf.float32)
            time_mask = tf.pad(
                tf.zeros((T, 1), dtype=tf.float32),
                [[t0, time_steps - t0 - T], [0, 0]],
                constant_values=1
            )
            return input_slice * time_mask

        return tf.map_fn(_apply_time_mask, inputs)

    def compute_mask(self, inputs, mask=None):
        return mask  # Pass through original mask

class FrequencyMasking(tf.keras.layers.Layer):
    def __init__(self, max_mask_length=5):
        super().__init__()
        self.max_mask_length = max_mask_length
        self.supports_masking = True  # Enable mask propagation

    def call(self, inputs, training=None):
        if not training:
            return inputs

        def _apply_frequency_mask(input_slice):
            time_steps = tf.shape(input_slice)[0]
            features = tf.shape(input_slice)[1]

            F = tf.random.uniform(shape=[], maxval=self.max_mask_length, dtype=tf.int32)
            F = tf.minimum(F, features)
            f0 = tf.random.uniform(shape=[], maxval=features - F, dtype=tf.int32)

            # Create 2D mask with broadcasting
            freq_mask = tf.pad(
                tf.zeros((1, F), dtype=tf.float32),
                [[0, 0], [f0, features - f0 - F]],
                constant_values=1
            )
            return input_slice * freq_mask

        return tf.map_fn(_apply_frequency_mask, inputs)

    def compute_mask(self, inputs, mask=None):
        return mask  # Pass through original mask

# ==============================================================
# 1. Data Preparation
# ==============================================================
def load_data(json_path):
    with open(json_path, "r") as f:
        data = json.load(f)
    X = np.array(data["mfcc"])[..., np.newaxis]
    X = np.squeeze(X)
    y = np.array(data["labels"])
    return X, y

X, y = load_data("/content/drive/MyDrive/preprocessed_mfcc_data1.json")

X_train_full, X_test, y_train_full, y_test = train_test_split(
    X, y, test_size=0.1, stratify=y, random_state=SEED
)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full, test_size=0.2, stratify=y_train_full, random_state=SEED
)

# ==============================================================
# 2. Augmented Model Architecture
# ==============================================================
def build_model(input_shape):
    model = models.Sequential([
        # Masking layer to skip time steps with zero values
        layers.Masking(mask_value=0., input_shape=input_shape),
        # Add Gaussian noise for regularization
        layers.GaussianNoise(stddev=0.01),
        # Custom time and frequency masking layers (if defined)
        TimeMasking(max_mask_length=10),
        FrequencyMasking(max_mask_length=5),
        # First Bidirectional GRU layer returning sequences for stacking
        layers.Bidirectional(layers.GRU(256, return_sequences=True)),
        layers.Dropout(0.3),
        # Second Bidirectional GRU layer returning the last output
        layers.Bidirectional(layers.GRU(128)),
        layers.Dropout(0.3),
        # Dense layers for classification
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(1, activation='sigmoid')
    ])
    return model

model = build_model(X_train.shape[1:])
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall')]
)
model.summary()

# ==============================================================
# 3. ASVspoof-Compliant Metrics Callbacks (Unchanged)
# ==============================================================
class EERCallback(callbacks.Callback):
    def __init__(self, validation_data):
        super().__init__()
        self.X_val, self.y_val = validation_data
        self.eers = []

    def on_epoch_end(self, epoch, logs=None):
        y_pred = self.model.predict(self.X_val, verbose=0).ravel()
        fpr, tpr, _ = roc_curve(self.y_val, y_pred)
        fnr = 1 - tpr
        eer = fpr[np.nanargmin(np.abs(fnr - fpr))]
        self.eers.append(eer)
        logs["val_eer"] = eer
        print(f"Val EER: {eer:.4f}")

class TDCFCallback(callbacks.Callback):
    def __init__(self, validation_data, **params):
        super().__init__()
        self.X_val, self.y_val = validation_data
        self.C1 = (params['pi_tar'] * (params['Cmiss_cm'] - params['Cmiss_asv'] * params['Pmiss_asv'])
                 - params['pi_non'] * params['Cfa_asv'] * params['Pfa_asv'])
        self.C2 = params['Cfa_cm'] * params['pi_spoof'] * (1 - params['Pmiss_spoof_asv'])
        self.min_C = min(self.C1, self.C2)
        self.min_tdcfs = []

    def on_epoch_end(self, epoch, logs=None):
        y_pred = self.model.predict(self.X_val, verbose=0).ravel()
        fpr, tpr, thresholds = roc_curve(self.y_val, y_pred)
        fnr = 1 - tpr
        min_tdcf = min((self.C1 * (1 - tpr[i]) + self.C2 * fpr[i]) / self.min_C
                      for i in range(len(thresholds)))
        self.min_tdcfs.append(min_tdcf)
        logs["val_min_tdcf"] = min_tdcf
        print(f"Val min-tDCF: {min_tdcf:.4f}")

# Callbacks setup
eer_callback = EERCallback((X_val, y_val))
tdcf_callback = TDCFCallback((X_val, y_val), **ASV_PARAMS)

metrics_callbacks = [
    eer_callback,
    tdcf_callback,
    callbacks.EarlyStopping(
        monitor='val_min_tdcf',
        patience=5,
        mode='min',
        restore_best_weights=True
    )
]

# ==============================================================
# 4. Training & Evaluation (Unchanged)
# ==============================================================
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=32,
    callbacks=metrics_callbacks,
    verbose=1
)


# ==============================================================
# 5. Final Evaluation (Test Set)
# ==============================================================
def compute_asvspoof_metrics(y_true, y_scores, **params):
    """Official ASVspoof 2019 metric computation"""
    # Compute EER
    fpr, tpr, thresholds = roc_curve(y_true, y_scores)
    fnr = 1 - tpr
    eer = fpr[np.nanargmin(np.abs(fnr - fpr))]

    # Compute t-DCF parameters
    C1 = (params['pi_tar'] * (params['Cmiss_cm'] - params['Cmiss_asv'] * params['Pmiss_asv'])
          - params['pi_non'] * params['Cfa_asv'] * params['Pfa_asv'])
    C2 = params['Cfa_cm'] * params['pi_spoof'] * (1 - params['Pmiss_spoof_asv'])
    min_C = min(C1, C2)

    # Find minimum t-DCF
    min_tdcf = float('inf')
    for thresh in thresholds:
        y_bin = (y_scores >= thresh).astype(int)
        Pmiss_cm = np.mean((y_bin == 0) & (y_true == 1))
        Pfa_cm = np.mean((y_bin == 1) & (y_true == 0))

        tdcf = C1 * Pmiss_cm + C2 * Pfa_cm
        tdcf_norm = tdcf / min_C if min_C > 0 else float('inf')

        if tdcf_norm < min_tdcf:
            min_tdcf = tdcf_norm

    return eer, min_tdcf

# Generate test predictions
y_test_scores = model.predict(X_test, verbose=0).ravel()

# Compute official metrics
test_eer, test_min_tdcf = compute_asvspoof_metrics(y_test, y_test_scores, **ASV_PARAMS)

# Default threshold metrics
y_pred_05 = (y_test_scores >= 0.5).astype(int)
test_metrics = {
    'accuracy': accuracy_score(y_test, y_pred_05),
    'precision': precision_score(y_test, y_pred_05),
    'recall': recall_score(y_test, y_pred_05),
    'f1': f1_score(y_test, y_pred_05)
}

# ==============================================================
# 6. Comprehensive Visualization
# ==============================================================
plt.figure(figsize=(18, 12))

# Training Dynamics
plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Training Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy')
plt.legend()

# ASVspoof Metrics
plt.subplot(2, 2, 3)
plt.plot(metrics_callbacks[0].eers, label='EER')
plt.title('Equal Error Rate Evolution')
plt.xlabel('Epochs')

plt.subplot(2, 2, 4)
plt.plot(metrics_callbacks[1].min_tdcfs, label='min-tDCF')
plt.title('Minimum t-DCF Evolution')
plt.xlabel('Epochs')

# Precision-Recall Analysis
plt.figure(figsize=(12, 5))
precision, recall, pr_thresholds = precision_recall_curve(y_test, y_test_scores)
plt.plot(recall, precision, label=f'PR Curve (AUC={auc(recall, precision):.2f})')
plt.title('Test Set Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.grid()

# Threshold Analysis
plt.figure(figsize=(12, 5))
fpr, tpr, roc_thresholds = roc_curve(y_test, y_test_scores)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC={auc(fpr, tpr):.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Chance')
plt.title('Receiver Operating Characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# 6.1 Confusion Matrix
cm = confusion_matrix(y_test, y_pred_05)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Spoof','Genuine'])
plt.figure()
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix (Threshold=0.5)')

# 6.2 DET Curve (FNR vs FPR)
fpr, tpr, det_thresh = roc_curve(y_test, y_test_scores)
fnr = 1 - tpr
plt.figure()
plt.plot(fpr, fnr)
plt.xlabel('False Positive Rate')
plt.ylabel('False Negative Rate')
plt.title('DET Curve')
plt.grid(True)

# 6.3 Score Distributions
plt.figure()
plt.hist(y_test_scores[y_test==1], bins=50, alpha=0.6, label='Genuine Scores')
plt.hist(y_test_scores[y_test==0], bins=50, alpha=0.6, label='Spoof Scores')
plt.title('Score Distributions')
plt.xlabel('Model Score')
plt.ylabel('Count')
plt.legend()

plt.show()
# ==============================================================
# 7. Final Reporting
# ==============================================================
print("\n=== ASVspoof 2019 Challenge Metrics ===")
print(f"Equal Error Rate (EER): {test_eer:.4f}")
print(f"Minimum Normalized t-DCF: {test_min_tdcf:.4f}")

print("\n=== Operational Metrics (Threshold=0.5) ===")
print(f"Accuracy: {test_metrics['accuracy']:.4f}")
print(f"Precision: {test_metrics['precision']:.4f}")
print(f"Recall: {test_metrics['recall']:.4f}")
print(f"F1-Score: {test_metrics['f1']:.4f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_05, target_names=["Spoof", "Genuine"]))

# ==============================================================
# 8. Model Export
# ==============================================================
model.save("BiGRU.h5")
print("\nModel saved successfully!")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/masking.py:47: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ masking (Masking)               │ (None, 130, 13)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise (GaussianNoise)  │ (None, 130, 13)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_masking (TimeMasking)      │ (None, 130, 13)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ frequency_masking               │ (None, 130, 13)        │             0 │
# │ (FrequencyMasking)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 130, 512)       │       416,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 130, 512)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 256)            │       493,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 975,361 (3.72 MB)
#  Trainable params: 975,361 (3.72 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7219 - loss: 0.5540 - precision: 0.7687 - recall: 0.8233Val EER: 0.1182
# Val min-tDCF: 0.3194
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 213s 2s/step - accuracy: 0.7226 - loss: 0.5530 - precision: 0.7693 - recall: 0.8236 - val_accuracy: 0.8697 - val_loss: 0.3364 - val_precision: 0.9754 - val_recall: 0.8180 - val_eer: 0.1182 - val_min_tdcf: 0.3194
# Epoch 2/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8255 - loss: 0.3778 - precision: 0.8842 - recall: 0.8423Val EER: 0.0878
# Val min-tDCF: 0.2322
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 187s 2s/step - accuracy: 0.8257 - loss: 0.3775 - precision: 0.8843 - recall: 0.8424 - val_accuracy: 0.9059 - val_loss: 0.2189 - val_precision: 0.9691 - val_recall: 0.8818 - val_eer: 0.0878 - val_min_tdcf: 0.2322
# Epoch 3/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8743 - loss: 0.3075 - precision: 0.9204 - recall: 0.8831Val EER: 0.0709
# Val min-tDCF: 0.2181
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 191s 2s/step - accuracy: 0.8743 - loss: 0.3075 - precision: 0.9204 - recall: 0.8831 - val_accuracy: 0.9047 - val_loss: 0.2069 - val_precision: 0.9652 - val_recall: 0.8837 - val_eer: 0.0709 - val_min_tdcf: 0.2181
# Epoch 4/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8753 - loss: 0.2860 - precision: 0.9180 - recall: 0.8877Val EER: 0.0642
# Val min-tDCF: 0.1813
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 187s 2s/step - accuracy: 0.8754 - loss: 0.2859 - precision: 0.9180 - recall: 0.8877 - val_accuracy: 0.9083 - val_loss: 0.2095 - val_precision: 0.9751 - val_recall: 0.8799 - val_eer: 0.0642 - val_min_tdcf: 0.1813
# Epoch 5/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8912 - loss: 0.2473 - precision: 0.9311 - recall: 0.8993Val EER: 0.0574
# Val min-tDCF: 0.1577
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 208s 2s/step - accuracy: 0.8912 - loss: 0.2473 - precision: 0.9311 - recall: 0.8993 - val_accuracy: 0.9349 - val_loss: 0.1552 - val_precision: 0.9687 - val_recall: 0.9287 - val_eer: 0.0574 - val_min_tdcf: 0.1577
# Epoch 6/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9049 - loss: 0.2249 - precision: 0.9441 - recall: 0.9077Val EER: 0.0642
# Val min-tDCF: 0.1586
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 207s 2s/step - accuracy: 0.9049 - loss: 0.2249 - precision: 0.9441 - recall: 0.9077 - val_accuracy: 0.9324 - val_loss: 0.1613 - val_precision: 0.9328 - val_recall: 0.9644 - val_eer: 0.0642 - val_min_tdcf: 0.1586
# Epoch 7/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9034 - loss: 0.2286 - precision: 0.9350 - recall: 0.9151Val EER: 0.0439
# Val min-tDCF: 0.1227
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 190s 2s/step - accuracy: 0.9035 - loss: 0.2285 - precision: 0.9351 - recall: 0.9151 - val_accuracy: 0.9554 - val_loss: 0.1179 - val_precision: 0.9751 - val_recall: 0.9550 - val_eer: 0.0439 - val_min_tdcf: 0.1227
# Epoch 8/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9217 - loss: 0.1978 - precision: 0.9414 - recall: 0.9382Val EER: 0.0473
# Val min-tDCF: 0.1154
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 186s 2s/step - accuracy: 0.9217 - loss: 0.1977 - precision: 0.9414 - recall: 0.9382 - val_accuracy: 0.9445 - val_loss: 0.1361 - val_precision: 0.9784 - val_recall: 0.9343 - val_eer: 0.0473 - val_min_tdcf: 0.1154
# Epoch 9/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9137 - loss: 0.2147 - precision: 0.9362 - recall: 0.9305Val EER: 0.0473
# Val min-tDCF: 0.1206
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.9138 - loss: 0.2145 - precision: 0.9363 - recall: 0.9306 - val_accuracy: 0.9409 - val_loss: 0.1431 - val_precision: 0.9764 - val_recall: 0.9306 - val_eer: 0.0473 - val_min_tdcf: 0.1206
# Epoch 10/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9142 - loss: 0.2052 - precision: 0.9424 - recall: 0.9247Val EER: 0.0439
# Val min-tDCF: 0.1077
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 219s 2s/step - accuracy: 0.9142 - loss: 0.2052 - precision: 0.9424 - recall: 0.9248 - val_accuracy: 0.9578 - val_loss: 0.1106 - val_precision: 0.9863 - val_recall: 0.9475 - val_eer: 0.0439 - val_min_tdcf: 0.1077
# Epoch 11/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9273 - loss: 0.1877 - precision: 0.9512 - recall: 0.9363Val EER: 0.0541
# Val min-tDCF: 0.1534
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 250s 2s/step - accuracy: 0.9273 - loss: 0.1876 - precision: 0.9512 - recall: 0.9363 - val_accuracy: 0.9337 - val_loss: 0.1555 - val_precision: 0.9938 - val_recall: 0.9024 - val_eer: 0.0541 - val_min_tdcf: 0.1534
# Epoch 12/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9157 - loss: 0.1967 - precision: 0.9449 - recall: 0.9246Val EER: 0.0270
# Val min-tDCF: 0.0663
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 190s 2s/step - accuracy: 0.9158 - loss: 0.1964 - precision: 0.9450 - recall: 0.9248 - val_accuracy: 0.9662 - val_loss: 0.0813 - val_precision: 0.9903 - val_recall: 0.9568 - val_eer: 0.0270 - val_min_tdcf: 0.0663
# Epoch 13/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9382 - loss: 0.1609 - precision: 0.9611 - recall: 0.9432Val EER: 0.0203
# Val min-tDCF: 0.0607
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 186s 2s/step - accuracy: 0.9382 - loss: 0.1609 - precision: 0.9610 - recall: 0.9432 - val_accuracy: 0.9735 - val_loss: 0.0843 - val_precision: 0.9688 - val_recall: 0.9906 - val_eer: 0.0203 - val_min_tdcf: 0.0607
# Epoch 14/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9463 - loss: 0.1493 - precision: 0.9576 - recall: 0.9598Val EER: 0.0236
# Val min-tDCF: 0.0654
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 205s 2s/step - accuracy: 0.9463 - loss: 0.1492 - precision: 0.9576 - recall: 0.9598 - val_accuracy: 0.9771 - val_loss: 0.0837 - val_precision: 0.9759 - val_recall: 0.9887 - val_eer: 0.0236 - val_min_tdcf: 0.0654
# Epoch 15/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9487 - loss: 0.1393 - precision: 0.9613 - recall: 0.9595Val EER: 0.0236
# Val min-tDCF: 0.0598
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 206s 2s/step - accuracy: 0.9487 - loss: 0.1392 - precision: 0.9613 - recall: 0.9596 - val_accuracy: 0.9723 - val_loss: 0.0703 - val_precision: 0.9705 - val_recall: 0.9869 - val_eer: 0.0236 - val_min_tdcf: 0.0598
# Epoch 16/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9455 - loss: 0.1372 - precision: 0.9578 - recall: 0.9584Val EER: 0.0169
# Val min-tDCF: 0.0381
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9456 - loss: 0.1372 - precision: 0.9579 - recall: 0.9584 - val_accuracy: 0.9867 - val_loss: 0.0443 - val_precision: 0.9888 - val_recall: 0.9906 - val_eer: 0.0169 - val_min_tdcf: 0.0381
# Epoch 17/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9462 - loss: 0.1344 - precision: 0.9548 - recall: 0.9628Val EER: 0.0304
# Val min-tDCF: 0.0788
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.9462 - loss: 0.1344 - precision: 0.9548 - recall: 0.9627 - val_accuracy: 0.9735 - val_loss: 0.0692 - val_precision: 0.9867 - val_recall: 0.9719 - val_eer: 0.0304 - val_min_tdcf: 0.0788
# Epoch 18/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9523 - loss: 0.1276 - precision: 0.9664 - recall: 0.9600Val EER: 0.0236
# Val min-tDCF: 0.0583
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 214s 2s/step - accuracy: 0.9523 - loss: 0.1276 - precision: 0.9664 - recall: 0.9600 - val_accuracy: 0.9771 - val_loss: 0.0585 - val_precision: 0.9849 - val_recall: 0.9794 - val_eer: 0.0236 - val_min_tdcf: 0.0583
# Epoch 19/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9495 - loss: 0.1369 - precision: 0.9629 - recall: 0.9590Val EER: 0.0236
# Val min-tDCF: 0.0485
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 193s 2s/step - accuracy: 0.9494 - loss: 0.1370 - precision: 0.9629 - recall: 0.9589 - val_accuracy: 0.9807 - val_loss: 0.0676 - val_precision: 0.9868 - val_recall: 0.9831 - val_eer: 0.0236 - val_min_tdcf: 0.0485
# Epoch 20/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9544 - loss: 0.1214 - precision: 0.9620 - recall: 0.9679Val EER: 0.0203
# Val min-tDCF: 0.0378
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.9544 - loss: 0.1214 - precision: 0.9621 - recall: 0.9678 - val_accuracy: 0.9807 - val_loss: 0.0489 - val_precision: 0.9887 - val_recall: 0.9812 - val_eer: 0.0203 - val_min_tdcf: 0.0378
# Epoch 21/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9640 - loss: 0.1121 - precision: 0.9719 - recall: 0.9725Val EER: 0.0236
# Val min-tDCF: 0.0411
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.9640 - loss: 0.1121 - precision: 0.9719 - recall: 0.9724 - val_accuracy: 0.9795 - val_loss: 0.0628 - val_precision: 0.9943 - val_recall: 0.9737 - val_eer: 0.0236 - val_min_tdcf: 0.0411
# Epoch 22/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9557 - loss: 0.1155 - precision: 0.9658 - recall: 0.9661Val EER: 0.0270
# Val min-tDCF: 0.0610
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 223s 2s/step - accuracy: 0.9557 - loss: 0.1155 - precision: 0.9658 - recall: 0.9660 - val_accuracy: 0.9759 - val_loss: 0.0702 - val_precision: 0.9961 - val_recall: 0.9662 - val_eer: 0.0270 - val_min_tdcf: 0.0610
# Epoch 23/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9572 - loss: 0.1195 - precision: 0.9650 - recall: 0.9691Val EER: 0.0169
# Val min-tDCF: 0.0420
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 241s 2s/step - accuracy: 0.9571 - loss: 0.1195 - precision: 0.9650 - recall: 0.9690 - val_accuracy: 0.9723 - val_loss: 0.0657 - val_precision: 0.9620 - val_recall: 0.9962 - val_eer: 0.0169 - val_min_tdcf: 0.0420
# Epoch 24/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9541 - loss: 0.1195 - precision: 0.9672 - recall: 0.9621Val EER: 0.0236
# Val min-tDCF: 0.0558
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 192s 2s/step - accuracy: 0.9541 - loss: 0.1196 - precision: 0.9671 - recall: 0.9621 - val_accuracy: 0.9783 - val_loss: 0.0674 - val_precision: 0.9831 - val_recall: 0.9831 - val_eer: 0.0236 - val_min_tdcf: 0.0558
# Epoch 25/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9587 - loss: 0.1117 - precision: 0.9651 - recall: 0.9716Val EER: 0.0270
# Val min-tDCF: 0.0540
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.9587 - loss: 0.1117 - precision: 0.9651 - recall: 0.9716 - val_accuracy: 0.9662 - val_loss: 0.0872 - val_precision: 0.9922 - val_recall: 0.9550 - val_eer: 0.0270 - val_min_tdcf: 0.0540
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# === ASVspoof 2019 Challenge Metrics ===
# Equal Error Rate (EER): 0.0182
# Minimum Normalized t-DCF: 0.0235
#
# === Operational Metrics (Threshold=0.5) ===
# Accuracy: 0.9848
# Precision: 0.9898
# Recall: 0.9865
# F1-Score: 0.9882
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Spoof       0.98      0.98      0.98       165
#      Genuine       0.99      0.99      0.99       296
#
#     accuracy                           0.98       461
#    macro avg       0.98      0.98      0.98       461
# weighted avg       0.98      0.98      0.98       461
#
#
# Model saved successfully!
