# %%
import json
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from sklearn.model_selection import train_test_split
from sklearn.metrics import (roc_curve, precision_recall_curve, auc,
                            confusion_matrix, ConfusionMatrixDisplay,
                            classification_report, accuracy_score)
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

# ==============================================================
# 0. Configuration & Reproducibility
# ==============================================================
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

# Official ASVspoof 2019 Challenge Parameters
ASV_PARAMS = {
    # ASV System Error Rates (Fixed at ASV's EER operating point)
    'Pmiss_asv': 0.01,         # ASV miss rate on target trials
    'Pfa_asv': 0.001,          # ASV false alarm rate on non-target trials
    'Pmiss_spoof_asv': 0.05,   # ASV miss rate on spoof trials

    # Cost Parameters
    'Cmiss_asv': 1,            # Cost of ASV miss
    'Cfa_asv': 1,              # Cost of ASV false alarm
    'Cmiss_cm': 1,             # Cost of CM miss
    'Cfa_cm': 10,              # Cost of CM false alarm

    # Prior Probabilities
    'pi_tar': 0.9405,          # Target speaker prior
    'pi_non': 0.0095,          # Non-target speaker prior
    'pi_spoof': 0.05           # Spoof prior
}

# ==============================================================
# 1. Data Preparation
# ==============================================================
def load_data(json_path):
    with open(json_path, "r") as f:
        data = json.load(f)
    X = np.array(data["mfcc"])[..., np.newaxis]  # Add channel dimension
    y = np.array(data["labels"])
    return X, y

X, y = load_data("/content/drive/MyDrive/preprocessed_mfcc_data1.json")

# Stratified splits preserving class distribution
X_train_full, X_test, y_train_full, y_test = train_test_split(
    X, y, test_size=0.1, stratify=y, random_state=SEED
)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full, test_size=0.2, stratify=y_train_full, random_state=SEED
)

# ==============================================================
# 2. Model Architecture (VGG-inspired)
# ==============================================================
def build_model(input_shape):
    model = models.Sequential([
        # Block 1
        layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=input_shape),
        layers.Conv2D(32, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D((2,2)),

        # Block 2
        layers.Conv2D(64, (3,3), activation='relu', padding='same'),
        layers.Conv2D(64, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D((2,2)),

        # Block 3
        layers.Conv2D(128, (3,3), activation='relu', padding='same'),
        layers.Conv2D(128, (3,3), activation='relu', padding='same'),
        layers.MaxPooling2D((2,2)),

        # Classifier
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(1, activation='sigmoid')
    ])
    return model

model = build_model(X_train.shape[1:])
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy',
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall')]
)
model.summary()

# ==============================================================
# 3. ASVspoof-Compliant Metrics Callbacks
# ==============================================================
class EERCallback(callbacks.Callback):
    """Computes Equal Error Rate (EER) according to ASVspoof protocol"""
    def __init__(self, validation_data):
        super().__init__()
        self.X_val, self.y_val = validation_data
        self.eers = []

    def on_epoch_end(self, epoch, logs=None):
        y_pred = self.model.predict(self.X_val, verbose=0).ravel()
        fpr, tpr, _ = roc_curve(self.y_val, y_pred)
        fnr = 1 - tpr
        eer = fpr[np.nanargmin(np.abs(fnr - fpr))]
        self.eers.append(eer)
        logs["val_eer"] = eer
        print(f"Val EER: {eer:.4f}")

class TDCFCallback(callbacks.Callback):
    """Official t-DCF implementation per ASVspoof 2019 guidelines"""
    def __init__(self, validation_data, **params):
        super().__init__()
        self.X_val, self.y_val = validation_data

        # Compute challenge parameters
        self.C1 = (params['pi_tar'] * (params['Cmiss_cm'] - params['Cmiss_asv'] * params['Pmiss_asv'])
                 - params['pi_non'] * params['Cfa_asv'] * params['Pfa_asv'])
        self.C2 = params['Cfa_cm'] * params['pi_spoof'] * (1 - params['Pmiss_spoof_asv'])
        self.min_C = min(self.C1, self.C2)
        self.min_tdcfs = []

    def on_epoch_end(self, epoch, logs=None):
        y_pred = self.model.predict(self.X_val, verbose=0).ravel()
        fpr, tpr, thresholds = roc_curve(self.y_val, y_pred)
        fnr = 1 - tpr

        min_tdcf = float('inf')
        for i in range(len(thresholds)):
            Pfa_cm = fpr[i]
            Pmiss_cm = fnr[i]

            tdcf = (self.C1 * Pmiss_cm) + (self.C2 * Pfa_cm)
            tdcf_norm = tdcf / self.min_C if self.min_C > 0 else float('inf')

            if tdcf_norm < min_tdcf:
                min_tdcf = tdcf_norm

        self.min_tdcfs.append(min_tdcf)
        logs["val_min_tdcf"] = min_tdcf
        print(f"Val min-tDCF: {min_tdcf:.4f}")

# 1. Create named references for clarity
eer_callback = EERCallback((X_val, y_val))
tdcf_callback = TDCFCallback((X_val, y_val), **ASV_PARAMS)

# ==============================================================
# 4. Training Setup
# ==============================================================
# 2. Pass to fit() via list
metrics_callbacks = [
    eer_callback,
    tdcf_callback,
    callbacks.EarlyStopping(
        monitor='val_min_tdcf',
        patience=5,
        mode='min',
        restore_best_weights=True
    )
]


history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=32,
    callbacks=metrics_callbacks,
    verbose=1
)

# ==============================================================
# 5. Final Evaluation (Test Set)
# ==============================================================
def compute_asvspoof_metrics(y_true, y_scores, **params):
    """Official ASVspoof 2019 metric computation"""
    # Compute EER
    fpr, tpr, thresholds = roc_curve(y_true, y_scores)
    fnr = 1 - tpr
    eer = fpr[np.nanargmin(np.abs(fnr - fpr))]

    # Compute t-DCF parameters
    C1 = (params['pi_tar'] * (params['Cmiss_cm'] - params['Cmiss_asv'] * params['Pmiss_asv'])
          - params['pi_non'] * params['Cfa_asv'] * params['Pfa_asv'])
    C2 = params['Cfa_cm'] * params['pi_spoof'] * (1 - params['Pmiss_spoof_asv'])
    min_C = min(C1, C2)

    # Find minimum t-DCF
    min_tdcf = float('inf')
    for thresh in thresholds:
        y_bin = (y_scores >= thresh).astype(int)
        Pmiss_cm = np.mean((y_bin == 0) & (y_true == 1))
        Pfa_cm = np.mean((y_bin == 1) & (y_true == 0))

        tdcf = C1 * Pmiss_cm + C2 * Pfa_cm
        tdcf_norm = tdcf / min_C if min_C > 0 else float('inf')

        if tdcf_norm < min_tdcf:
            min_tdcf = tdcf_norm

    return eer, min_tdcf

# Generate test predictions
y_test_scores = model.predict(X_test, verbose=0).ravel()

# Compute official metrics
test_eer, test_min_tdcf = compute_asvspoof_metrics(y_test, y_test_scores, **ASV_PARAMS)

# Default threshold metrics
y_pred_05 = (y_test_scores >= 0.5).astype(int)
test_metrics = {
    'accuracy': accuracy_score(y_test, y_pred_05),
    'precision': precision_score(y_test, y_pred_05),
    'recall': recall_score(y_test, y_pred_05),
    'f1': f1_score(y_test, y_pred_05)
}

# ==============================================================
# 6. Comprehensive Visualization
# ==============================================================
plt.figure(figsize=(18, 12))

# Training Dynamics
plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Training Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy')
plt.legend()

# ASVspoof Metrics
plt.subplot(2, 2, 3)
plt.plot(metrics_callbacks[0].eers, label='EER')
plt.title('Equal Error Rate Evolution')
plt.xlabel('Epochs')

plt.subplot(2, 2, 4)
plt.plot(metrics_callbacks[1].min_tdcfs, label='min-tDCF')
plt.title('Minimum t-DCF Evolution')
plt.xlabel('Epochs')

# Precision-Recall Analysis
plt.figure(figsize=(12, 5))
precision, recall, pr_thresholds = precision_recall_curve(y_test, y_test_scores)
plt.plot(recall, precision, label=f'PR Curve (AUC={auc(recall, precision):.2f})')
plt.title('Test Set Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.grid()

# Threshold Analysis
plt.figure(figsize=(12, 5))
fpr, tpr, roc_thresholds = roc_curve(y_test, y_test_scores)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC={auc(fpr, tpr):.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Chance')
plt.title('Receiver Operating Characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# 6.1 Confusion Matrix
cm = confusion_matrix(y_test, y_pred_05)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Spoof','Genuine'])
plt.figure()
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix (Threshold=0.5)')

# 6.2 DET Curve (FNR vs FPR)
fpr, tpr, det_thresh = roc_curve(y_test, y_test_scores)
fnr = 1 - tpr
plt.figure()
plt.plot(fpr, fnr)
plt.xlabel('False Positive Rate')
plt.ylabel('False Negative Rate')
plt.title('DET Curve')
plt.grid(True)

# 6.3 Score Distributions
plt.figure()
plt.hist(y_test_scores[y_test==1], bins=50, alpha=0.6, label='Genuine Scores')
plt.hist(y_test_scores[y_test==0], bins=50, alpha=0.6, label='Spoof Scores')
plt.title('Score Distributions')
plt.xlabel('Model Score')
plt.ylabel('Count')
plt.legend()

plt.show()
# ==============================================================
# 7. Final Reporting
# ==============================================================
print("\n=== ASVspoof 2019 Challenge Metrics ===")
print(f"Equal Error Rate (EER): {test_eer:.4f}")
print(f"Minimum Normalized t-DCF: {test_min_tdcf:.4f}")

print("\n=== Operational Metrics (Threshold=0.5) ===")
print(f"Accuracy: {test_metrics['accuracy']:.4f}")
print(f"Precision: {test_metrics['precision']:.4f}")
print(f"Recall: {test_metrics['recall']:.4f}")
print(f"F1-Score: {test_metrics['f1']:.4f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_05, target_names=["Spoof", "Genuine"]))

# ==============================================================
# 8. Model Export
# ==============================================================
model.save("VGGNET.h5")
print("\nModel saved successfully!")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 130, 13, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 130, 13, 32)    │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 65, 6, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 65, 6, 64)      │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 65, 6, 64)      │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 3, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 3, 128)     │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 32, 3, 128)     │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 1, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 811,233 (3.09 MB)
#  Trainable params: 811,233 (3.09 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.6323 - loss: 1.9891 - precision: 0.6887 - recall: 0.7906Val EER: 0.1115
# Val min-tDCF: 0.3050
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 51s 456ms/step - accuracy: 0.6333 - loss: 1.9780 - precision: 0.6894 - recall: 0.7911 - val_accuracy: 0.8685 - val_loss: 0.2871 - val_precision: 0.9511 - val_recall: 0.8386 - val_eer: 0.1115 - val_min_tdcf: 0.3050
# Epoch 2/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.8646 - loss: 0.2966 - precision: 0.9185 - recall: 0.8690Val EER: 0.0676
# Val min-tDCF: 0.1951
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 46s 447ms/step - accuracy: 0.8647 - loss: 0.2965 - precision: 0.9185 - recall: 0.8691 - val_accuracy: 0.8938 - val_loss: 0.2359 - val_precision: 0.9826 - val_recall: 0.8499 - val_eer: 0.0676 - val_min_tdcf: 0.1951
# Epoch 3/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.9062 - loss: 0.2264 - precision: 0.9386 - recall: 0.9157Val EER: 0.0541
# Val min-tDCF: 0.1359
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 81s 434ms/step - accuracy: 0.9063 - loss: 0.2263 - precision: 0.9387 - recall: 0.9158 - val_accuracy: 0.9252 - val_loss: 0.1617 - val_precision: 0.9836 - val_recall: 0.8987 - val_eer: 0.0541 - val_min_tdcf: 0.1359
# Epoch 4/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9337 - loss: 0.1807 - precision: 0.9493 - recall: 0.9485Val EER: 0.0507
# Val min-tDCF: 0.1230
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 82s 432ms/step - accuracy: 0.9337 - loss: 0.1805 - precision: 0.9493 - recall: 0.9485 - val_accuracy: 0.9397 - val_loss: 0.1567 - val_precision: 0.9820 - val_recall: 0.9231 - val_eer: 0.0507 - val_min_tdcf: 0.1230
# Epoch 5/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9386 - loss: 0.1584 - precision: 0.9562 - recall: 0.9492Val EER: 0.0473
# Val min-tDCF: 0.1163
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 82s 434ms/step - accuracy: 0.9387 - loss: 0.1582 - precision: 0.9563 - recall: 0.9493 - val_accuracy: 0.9493 - val_loss: 0.1768 - val_precision: 0.9786 - val_recall: 0.9418 - val_eer: 0.0473 - val_min_tdcf: 0.1163
# Epoch 6/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9388 - loss: 0.1464 - precision: 0.9554 - recall: 0.9504Val EER: 0.0439
# Val min-tDCF: 0.1191
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 85s 462ms/step - accuracy: 0.9389 - loss: 0.1462 - precision: 0.9555 - recall: 0.9505 - val_accuracy: 0.9542 - val_loss: 0.1989 - val_precision: 0.9769 - val_recall: 0.9512 - val_eer: 0.0439 - val_min_tdcf: 0.1191
# Epoch 7/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.9563 - loss: 0.1174 - precision: 0.9631 - recall: 0.9699Val EER: 0.0507
# Val min-tDCF: 0.1114
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 79s 434ms/step - accuracy: 0.9563 - loss: 0.1173 - precision: 0.9632 - recall: 0.9699 - val_accuracy: 0.9385 - val_loss: 0.2263 - val_precision: 0.9820 - val_recall: 0.9212 - val_eer: 0.0507 - val_min_tdcf: 0.1114
# Epoch 8/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9615 - loss: 0.1103 - precision: 0.9720 - recall: 0.9689Val EER: 0.0338
# Val min-tDCF: 0.0945
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 82s 433ms/step - accuracy: 0.9616 - loss: 0.1101 - precision: 0.9720 - recall: 0.9690 - val_accuracy: 0.9662 - val_loss: 0.1225 - val_precision: 0.9720 - val_recall: 0.9756 - val_eer: 0.0338 - val_min_tdcf: 0.0945
# Epoch 9/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9712 - loss: 0.0764 - precision: 0.9787 - recall: 0.9771Val EER: 0.0405
# Val min-tDCF: 0.0878
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 83s 440ms/step - accuracy: 0.9712 - loss: 0.0764 - precision: 0.9787 - recall: 0.9771 - val_accuracy: 0.9650 - val_loss: 0.1588 - val_precision: 0.9737 - val_recall: 0.9719 - val_eer: 0.0405 - val_min_tdcf: 0.0878
# Epoch 10/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9690 - loss: 0.0729 - precision: 0.9761 - recall: 0.9766Val EER: 0.0372
# Val min-tDCF: 0.0798
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 82s 438ms/step - accuracy: 0.9690 - loss: 0.0729 - precision: 0.9761 - recall: 0.9766 - val_accuracy: 0.9614 - val_loss: 0.1671 - val_precision: 0.9465 - val_recall: 0.9962 - val_eer: 0.0372 - val_min_tdcf: 0.0798
# Epoch 11/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9704 - loss: 0.0760 - precision: 0.9736 - recall: 0.9810Val EER: 0.0405
# Val min-tDCF: 0.0881
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 85s 468ms/step - accuracy: 0.9704 - loss: 0.0760 - precision: 0.9736 - recall: 0.9810 - val_accuracy: 0.9626 - val_loss: 0.2131 - val_precision: 0.9466 - val_recall: 0.9981 - val_eer: 0.0405 - val_min_tdcf: 0.0881
# Epoch 12/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9700 - loss: 0.0826 - precision: 0.9739 - recall: 0.9805Val EER: 0.0372
# Val min-tDCF: 0.0801
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 46s 441ms/step - accuracy: 0.9701 - loss: 0.0823 - precision: 0.9740 - recall: 0.9805 - val_accuracy: 0.9698 - val_loss: 0.1348 - val_precision: 0.9669 - val_recall: 0.9869 - val_eer: 0.0372 - val_min_tdcf: 0.0801
# Epoch 13/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9755 - loss: 0.0696 - precision: 0.9814 - recall: 0.9809Val EER: 0.0405
# Val min-tDCF: 0.1083
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 83s 448ms/step - accuracy: 0.9756 - loss: 0.0695 - precision: 0.9814 - recall: 0.9809 - val_accuracy: 0.9578 - val_loss: 0.2200 - val_precision: 0.9560 - val_recall: 0.9794 - val_eer: 0.0405 - val_min_tdcf: 0.1083
# Epoch 14/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.9777 - loss: 0.0548 - precision: 0.9795 - recall: 0.9867Val EER: 0.0236
# Val min-tDCF: 0.0558
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 85s 477ms/step - accuracy: 0.9777 - loss: 0.0547 - precision: 0.9796 - recall: 0.9867 - val_accuracy: 0.9783 - val_loss: 0.1395 - val_precision: 0.9831 - val_recall: 0.9831 - val_eer: 0.0236 - val_min_tdcf: 0.0558
# Epoch 15/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9940 - loss: 0.0189 - precision: 0.9961 - recall: 0.9946Val EER: 0.0439
# Val min-tDCF: 0.1154
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 78s 438ms/step - accuracy: 0.9940 - loss: 0.0190 - precision: 0.9961 - recall: 0.9945 - val_accuracy: 0.9554 - val_loss: 0.2619 - val_precision: 0.9662 - val_recall: 0.9644 - val_eer: 0.0439 - val_min_tdcf: 0.1154
# Epoch 16/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9812 - loss: 0.0593 - precision: 0.9831 - recall: 0.9885Val EER: 0.0439
# Val min-tDCF: 0.0829
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 47s 453ms/step - accuracy: 0.9813 - loss: 0.0591 - precision: 0.9831 - recall: 0.9885 - val_accuracy: 0.9698 - val_loss: 0.1528 - val_precision: 0.9721 - val_recall: 0.9812 - val_eer: 0.0439 - val_min_tdcf: 0.0829
# Epoch 17/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9914 - loss: 0.0330 - precision: 0.9934 - recall: 0.9935Val EER: 0.0372
# Val min-tDCF: 0.0700
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 80s 433ms/step - accuracy: 0.9914 - loss: 0.0330 - precision: 0.9933 - recall: 0.9934 - val_accuracy: 0.9735 - val_loss: 0.1459 - val_precision: 0.9740 - val_recall: 0.9850 - val_eer: 0.0372 - val_min_tdcf: 0.0700
# Epoch 18/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.9773 - loss: 0.0677 - precision: 0.9830 - recall: 0.9821Val EER: 0.0338
# Val min-tDCF: 0.0908
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 84s 455ms/step - accuracy: 0.9774 - loss: 0.0676 - precision: 0.9830 - recall: 0.9822 - val_accuracy: 0.9650 - val_loss: 0.1559 - val_precision: 0.9701 - val_recall: 0.9756 - val_eer: 0.0338 - val_min_tdcf: 0.0908
# Epoch 19/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9877 - loss: 0.0314 - precision: 0.9921 - recall: 0.9890Val EER: 0.0236
# Val min-tDCF: 0.0528
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 80s 432ms/step - accuracy: 0.9877 - loss: 0.0314 - precision: 0.9922 - recall: 0.9890 - val_accuracy: 0.9771 - val_loss: 0.1101 - val_precision: 0.9759 - val_recall: 0.9887 - val_eer: 0.0236 - val_min_tdcf: 0.0528
# Epoch 20/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.9974 - loss: 0.0095 - precision: 0.9974 - recall: 0.9985Val EER: 0.0203
# Val min-tDCF: 0.0534
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 46s 438ms/step - accuracy: 0.9974 - loss: 0.0095 - precision: 0.9974 - recall: 0.9985 - val_accuracy: 0.9795 - val_loss: 0.1321 - val_precision: 0.9850 - val_recall: 0.9831 - val_eer: 0.0203 - val_min_tdcf: 0.0534
# Epoch 21/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9926 - loss: 0.0227 - precision: 0.9948 - recall: 0.9938Val EER: 0.0439
# Val min-tDCF: 0.1239
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 83s 446ms/step - accuracy: 0.9926 - loss: 0.0229 - precision: 0.9948 - recall: 0.9938 - val_accuracy: 0.9493 - val_loss: 0.2351 - val_precision: 0.9423 - val_recall: 0.9812 - val_eer: 0.0439 - val_min_tdcf: 0.1239
# Epoch 22/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9760 - loss: 0.0831 - precision: 0.9816 - recall: 0.9816Val EER: 0.0203
# Val min-tDCF: 0.0485
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 81s 435ms/step - accuracy: 0.9761 - loss: 0.0828 - precision: 0.9817 - recall: 0.9816 - val_accuracy: 0.9759 - val_loss: 0.1103 - val_precision: 0.9706 - val_recall: 0.9925 - val_eer: 0.0203 - val_min_tdcf: 0.0485
# Epoch 23/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.9833 - loss: 0.0455 - precision: 0.9858 - recall: 0.9886Val EER: 0.0236
# Val min-tDCF: 0.0457
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 83s 440ms/step - accuracy: 0.9833 - loss: 0.0455 - precision: 0.9858 - recall: 0.9885 - val_accuracy: 0.9783 - val_loss: 0.0941 - val_precision: 0.9868 - val_recall: 0.9794 - val_eer: 0.0236 - val_min_tdcf: 0.0457
# Epoch 24/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9985 - loss: 0.0089 - precision: 0.9987 - recall: 0.9990Val EER: 0.0270
# Val min-tDCF: 0.0697
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 45s 430ms/step - accuracy: 0.9985 - loss: 0.0089 - precision: 0.9986 - recall: 0.9990 - val_accuracy: 0.9735 - val_loss: 0.1372 - val_precision: 0.9848 - val_recall: 0.9737 - val_eer: 0.0270 - val_min_tdcf: 0.0697
# Epoch 25/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9934 - loss: 0.0142 - precision: 0.9948 - recall: 0.9950Val EER: 0.0304
# Val min-tDCF: 0.0841
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 84s 450ms/step - accuracy: 0.9934 - loss: 0.0143 - precision: 0.9948 - recall: 0.9950 - val_accuracy: 0.9698 - val_loss: 0.1874 - val_precision: 0.9757 - val_recall: 0.9775 - val_eer: 0.0304 - val_min_tdcf: 0.0841
# Epoch 26/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9861 - loss: 0.0478 - precision: 0.9895 - recall: 0.9893Val EER: 0.0203
# Val min-tDCF: 0.0451
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 81s 437ms/step - accuracy: 0.9861 - loss: 0.0476 - precision: 0.9896 - recall: 0.9894 - val_accuracy: 0.9723 - val_loss: 0.1483 - val_precision: 0.9636 - val_recall: 0.9944 - val_eer: 0.0203 - val_min_tdcf: 0.0451
# Epoch 27/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9855 - loss: 0.0389 - precision: 0.9873 - recall: 0.9903Val EER: 0.0372
# Val min-tDCF: 0.0948
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 82s 433ms/step - accuracy: 0.9855 - loss: 0.0389 - precision: 0.9873 - recall: 0.9903 - val_accuracy: 0.9638 - val_loss: 0.1428 - val_precision: 0.9632 - val_recall: 0.9812 - val_eer: 0.0372 - val_min_tdcf: 0.0948
# Epoch 28/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.9945 - loss: 0.0300 - precision: 0.9963 - recall: 0.9954Val EER: 0.0169
# Val min-tDCF: 0.0384
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 83s 445ms/step - accuracy: 0.9946 - loss: 0.0299 - precision: 0.9963 - recall: 0.9955 - val_accuracy: 0.9807 - val_loss: 0.1046 - val_precision: 0.9743 - val_recall: 0.9962 - val_eer: 0.0169 - val_min_tdcf: 0.0384
# Epoch 29/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9933 - loss: 0.0150 - precision: 0.9939 - recall: 0.9957Val EER: 0.0270
# Val min-tDCF: 0.0448
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 47s 449ms/step - accuracy: 0.9933 - loss: 0.0150 - precision: 0.9939 - recall: 0.9957 - val_accuracy: 0.9819 - val_loss: 0.1651 - val_precision: 0.9779 - val_recall: 0.9944 - val_eer: 0.0270 - val_min_tdcf: 0.0448
# Epoch 30/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.9816 - loss: 0.0701 - precision: 0.9865 - recall: 0.9851Val EER: 0.0236
# Val min-tDCF: 0.0684
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 84s 467ms/step - accuracy: 0.9816 - loss: 0.0699 - precision: 0.9865 - recall: 0.9851 - val_accuracy: 0.9759 - val_loss: 0.1725 - val_precision: 0.9867 - val_recall: 0.9756 - val_eer: 0.0236 - val_min_tdcf: 0.0684
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# === ASVspoof 2019 Challenge Metrics ===
# Equal Error Rate (EER): 0.0242
# Minimum Normalized t-DCF: 0.0236
#
# === Operational Metrics (Threshold=0.5) ===
# Accuracy: 0.9718
# Precision: 0.9609
# Recall: 0.9966
# F1-Score: 0.9784
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Spoof       0.99      0.93      0.96       165
#      Genuine       0.96      1.00      0.98       296
#
#     accuracy                           0.97       461
#    macro avg       0.98      0.96      0.97       461
# weighted avg       0.97      0.97      0.97       461
#
#
# Model saved successfully!
